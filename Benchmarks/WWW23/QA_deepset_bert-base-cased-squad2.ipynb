# %%
import json
import re
from tqdm import tqdm
with open("./Accord_all_contract.json", "r") as f:
    templates = json.load(f)

# %%
from transformers import AutoModelForQuestionAnswering, AutoTokenizer, pipeline

model_name = "deepset/bert-base-cased-squad2"

# a) Get predictions
nlp = pipeline('question-answering',
               model=model_name,
               tokenizer=model_name,
                  device=0,)
QA_input = {
    'question': 'Why is model conversion important?',
    'context': 'The option to convert models between FARM and transformers gives freedom to the user and let people easily switch between frameworks.'
}
res = nlp(QA_input)
# Out:
# 2023-02-07 09:34:02.516810: I tensorflow/stream_executor/platform/default/dso_loader.cc:53] Successfully opened dynamic library libcudart.so.11.0
# Downloading:   0%|          | 0.00/508 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/433M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/152 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/213k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
with open("./templates_data.json", 'r') as f:
    templates_data = json.load(f)

# %%
data = {}
from urllib.parse import unquote
for k in set(templates.keys()).intersection(templates_data.keys()):
    data[k] = {
        "input_text": "".join(templates[k]['/text/sample.md']),
        "cicero": "".join(templates[k]['/text/grammar.tem.md']),
        "ciceroMarks": re.findall("(?<=\{{).+?(?=\}})", 
                         "".join(templates[k]['/text/grammar.tem.md'])),
        "QAs": [],
    }
    for variable_name, variable_value in templates_data[k].items():
        origin_value = variable_value
        if "$" == variable_name[0] or variable_name in ['clauseId', 'contractId']:
            continue
        try:
            try:
                variable_value = json.loads(variable_value.replace("'", '"'))
            except Exception as e:
#                 print(variable_value, e)
                pass
            if '.PostalAddress' in variable_value['$class']:
                continue
            for key in variable_value.keys():
                if 'text' in key.lower():
                    variable_value = variable_value['key']
                elif key in ['amount']:
                    if 'unit' in variable_value.keys():
                        variable_value = f"{variable_value[key]} {variable_value['unit']}"
                    else:
                        print("QQQQQQ", key , variable_value)
                    break
                elif 'value' in key.lower():
                    variable_value = f"{variable_value[key]} {variable_value['currencyCode']}"
                    break
                
            ans = variable_value
        except Exception as e:
            if variable_name == "termination":
                print(e)
            variable_value = str(variable_value)
            ans = unquote(variable_value.split(".")[-1].split("#")[-1])
        if type(ans) == dict:
            continue
        data[k]["QAs"].append({
            "variable_name": variable_name,
            "ans": ans,
            'variable_value': origin_value
        })

# %%
outputs = []
for k, v in tqdm(data.items()):
    for questions in v['QAs']:
        QA_input = {
            'context': v['input_text'],
            'question': f"What is the {questions['variable_name']}?",

        }
        res = nlp(QA_input)
        outputs.append({
            'score': res['score'],
            'model_output': res['answer']\
                            .replace(".00", "")\
                            .replace("\n", ""),
            'true_ans': questions['ans'],
            "k": k,
        })
#     break
# Out:
#   0%|                                   | 0/53 [00:00<?, ?it/s]/home/eason/anaconda3/envs/py37/lib/python3.7/site-packages/transformers/pipelines/base.py:1046: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   UserWarning,
# 100%|██████████████████████████| 53/53 [00:25<00:00,  2.07it/s]

# %%
from utils import compute_exact_match, compute_f1

# %%
import numpy as np
all_f1 = []
all_em = []
for output in outputs:
    f1 = compute_f1(output['model_output'], output['true_ans'])
    em = compute_exact_match(output['model_output'], output['true_ans'])
    output['f1'] = f1
    output['em'] = em
    all_f1.append(f1)
    all_em.append(em)
all_f1 = np.array(all_f1)
all_em = np.array(all_em)

# %%
all_em.mean()
# Out:
# 0.12761020881670534

# %%
all_f1.mean()
# Out:
# 0.1845320289403816

# %%
compute_f1("500.00 USD", "500 USD")

# %%
outputs
# Out:
# [{'score': 0.08069667220115662,
#   'model_output': '500 USD',
#   'true_ans': '1000 USD',
#   'k': 'promissory-note',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.03271443769335747,
#   'model_output': 'date and year first above written',
#   'true_ans': '000-04:00',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.29684826731681824,
#   'model_output': '1 Main Street',
#   'true_ans': 'Daniel',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.09983028471469879,
#   'model_output': '3.8% per annum',
#   'true_ans': '8',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.045817065984010696,
#   'model_output': 'an individual residing at "1 Main Street" (“Maker”),',
#   'true_ans': 'True',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.5527288913726807,
#   'model_output': '1 Main Street',
#   'true_ans': '1 Main Street',
#   'k': 'promissory-note',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.12172137200832367,
#   'model_output': 'Clause Inc.",',
#   'true_ans': '',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.007093722932040691,
#   'model_output': 'Waiver.',
#   'true_ans': 'CORP',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.019472314044833183,
#   'model_output': 'the “Company”),',
#   'true_ans': '246 5th Ave, 3rd Fl, New York, NY 10001',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.3368169367313385,
#   'model_output': '500 USD',
#   'true_ans': '500 USD',
#   'k': 'promissory-note',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.01880735717713833,
#   'model_output': '90 days',
#   'true_ans': '000-04:00',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.007815718650817871,
#   'model_output': 'Event of Default',
#   'true_ans': '90',
#   'k': 'promissory-note',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.007266184780746698,
#   'model_output': '90 days',
#   'true_ans': '90',
#   'k': 'promissory-note',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.01555472519248724,
#   'model_output': 'New York, NY',
#   'true_ans': 'New York, NY',
#   'k': 'promissory-note',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.09916968643665314,
#   'model_output': 'Betty Buyer',
#   'true_ans': 'Betty Buyer',
#   'k': 'minilatedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.03558086231350899,
#   'model_output': 'Steve Seller" shall pay to"Betty Buyer',
#   'true_ans': 'Steve Seller',
#   'k': 'minilatedeliveryandpenalty',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.062197599560022354,
#   'model_output': 'more than 15 days',
#   'true_ans': '2 days',
#   'k': 'minilatedeliveryandpenalty',
#   'f1': 0.3333333333333333,
#   'em': 0},
#  {'score': 0.2393839806318283,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'minilatedeliveryandpenalty',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.5004382729530334,
#   'model_output': '15 days',
#   'true_ans': '15 days',
#   'k': 'minilatedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.2391045093536377,
#   'model_output': '1,000 USD',
#   'true_ans': '1000 USD',
#   'k': 'promissory-note-md',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.03064512461423874,
#   'model_output': '01/30/2018',
#   'true_ans': '000-04:00',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.2840108871459961,
#   'model_output': '1 Main Street',
#   'true_ans': 'Daniel',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.28486624360084534,
#   'model_output': '3.8% per annum',
#   'true_ans': '8',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04054226726293564,
#   'model_output': 'an individual residing at "1 Main Street" (“Maker”),',
#   'true_ans': 'True',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.44042205810546875,
#   'model_output': '1 Main Street',
#   'true_ans': '1 Main Street',
#   'k': 'promissory-note-md',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.03615627810359001,
#   'model_output': 'Clause Inc.",',
#   'true_ans': '',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.007456357590854168,
#   'model_output': 'The obligations of the Maker hereunder shall bind his heirs and permitted assigns',
#   'true_ans': 'CORP',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.027209607884287834,
#   'model_output': 'the “Company”),',
#   'true_ans': '246 5th Ave, 3rd Fl, New York, NY 10001',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.018481973558664322,
#   'model_output': 'year first above written',
#   'true_ans': '000-04:00',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.02817179076373577,
#   'model_output': 'Maker without the prior written consent of the Lender',
#   'true_ans': '90',
#   'k': 'promissory-note-md',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0033419800456613302,
#   'model_output': '90 days',
#   'true_ans': '90',
#   'k': 'promissory-note-md',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.007755199912935495,
#   'model_output': 'New York, NY',
#   'true_ans': 'New York, NY',
#   'k': 'promissory-note-md',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.180996835231781,
#   'model_output': 'four point five" percent (4.5%) of the Net Sales Price',
#   'true_ans': 'four point five',
#   'k': 'ip-payment',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.12294953316450119,
#   'model_output': 'four point five" percent',
#   'true_ans': '5',
#   'k': 'ip-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0013779961736872792,
#   'model_output': 'any rights granted to it under this Agreement',
#   'true_ans': 'five point two',
#   'k': 'ip-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.001475088531151414,
#   'model_output': 'four point five" percent',
#   'true_ans': '2',
#   'k': 'ip-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.16133978962898254,
#   'model_output': '7 days business days',
#   'true_ans': '10 days',
#   'k': 'ip-payment',
#   'f1': 0.3333333333333333,
#   'em': 0},
#  {'score': 0.05662604421377182,
#   'model_output': 'within 7 days business days',
#   'true_ans': '7 days',
#   'k': 'ip-payment',
#   'f1': 0.5714285714285715,
#   'em': 0},
#  {'score': 0.004156170412898064,
#   'model_output': 'BUYER CORPORATION',
#   'true_ans': 'SUPPLIER CORPORATION',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.009354461915791035,
#   'model_output': 'The Supplier',
#   'true_ans': 'BUYER CORPORATION',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.02559899538755417,
#   'model_output': 'Delivery Date").',
#   'true_ans': 'Grade I, Size 4, Zutano Mexican Avocados',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.03179069235920906,
#   'model_output': '06/30/2099',
#   'true_ans': '000-04:00',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.19613145291805267,
#   'model_output': '0.2',
#   'true_ans': '1.5 USD',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.17042496800422668,
#   'model_output': 'price',
#   'true_ans': 'KG',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.012565365061163902,
#   'model_output': '0.2',
#   'true_ans': '2995',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04050055518746376,
#   'model_output': '0.2',
#   'true_ans': '3005',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.3023889660835266,
#   'model_output': 'Zutano Mexican Avocados',
#   'true_ans': 'Grade I, Size 4, Zutano Mexican Avocados',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0.6,
#   'em': 0},
#  {'score': 0.40728628635406494,
#   'model_output': '0.2',
#   'true_ans': '1',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0589764341711998,
#   'model_output': '2 years',
#   'true_ans': 'hours',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07795222103595734,
#   'model_output': 'between 2°C and 13°',
#   'true_ans': '2',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04673190787434578,
#   'model_output': 'between 2°C and 13°',
#   'true_ans': '13',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.18153585493564606,
#   'model_output': 'between 70% and 90%.',
#   'true_ans': '70',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.13585935533046722,
#   'model_output': 'between 70% and 90%.',
#   'true_ans': '90',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.8382354974746704,
#   'model_output': '0.2',
#   'true_ans': '2',
#   'k': 'supplyagreement-perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04740051180124283,
#   'model_output': 'FooBarAtor',
#   'true_ans': 'ACME',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.002678615739569068,
#   'model_output': 'Certificate of Incorporation',
#   'true_ans': 'NY',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.06444499641656876,
#   'model_output': '555 oak street',
#   'true_ans': '555 main street',
#   'k': 'certificate-of-incorporation',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.002170761115849018,
#   'model_output': '555 oak street',
#   'true_ans': 'Manhattan',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0003067137149628252,
#   'model_output': '"FooBarAtor',
#   'true_ans': 'New York',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00036583980545401573,
#   'model_output': '10001',
#   'true_ans': '10001',
#   'k': 'certificate-of-incorporation',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.06144446134567261,
#   'model_output': 'Andie Agent',
#   'true_ans': 'Andie Agent',
#   'k': 'certificate-of-incorporation',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.163491353392601,
#   'model_output': '04/01/2019',
#   'true_ans': '000-04:00',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 8.767854160396382e-05,
#   'model_output': '## Section VII',
#   'true_ans': '400',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.000921493221540004,
#   'model_output': 'Section VIII',
#   'true_ans': '1',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.014182602986693382,
#   'model_output': 'mailing address',
#   'true_ans': 'FooBarAtor',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.037108708173036575,
#   'model_output': 'mailing',
#   'true_ans': '555 oak street',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00344598270021379,
#   'model_output': 'FooBarAtor',
#   'true_ans': 'Baltimore',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0012193307047709823,
#   'model_output': '/s/\t"FooBarAtor',
#   'true_ans': 'MD',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.02268819697201252,
#   'model_output': 'The name and mailing address',
#   'true_ans': '21201',
#   'k': 'certificate-of-incorporation',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.16451796889305115,
#   'model_output': 'Steve',
#   'true_ans': 'Steve',
#   'k': 'fragile-goods',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.4070955514907837,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'fragile-goods',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.015097164548933506,
#   'model_output': '1000 USD per unit of Equipment',
#   'true_ans': '1000 USD',
#   'k': 'fragile-goods',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.023250892758369446,
#   'model_output': '-0.5g and 0.5g',
#   'true_ans': '5',
#   'k': 'fragile-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.011448122560977936,
#   'model_output': '-0.5g and 0.5g',
#   'true_ans': '5',
#   'k': 'fragile-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00011755130981327966,
#   'model_output': '200 USD',
#   'true_ans': '5 USD',
#   'k': 'fragile-goods',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.0049329535104334354,
#   'model_output': 'no later than 10 seconds after initiation',
#   'true_ans': '10 seconds',
#   'k': 'fragile-goods',
#   'f1': 0.4444444444444445,
#   'em': 0},
#  {'score': 0.002192110288888216,
#   'model_output': '200 USD',
#   'true_ans': '200 USD',
#   'k': 'fragile-goods',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.14035561680793762,
#   'model_output': 'Betty Buyer',
#   'true_ans': 'Steve Seller',
#   'k': 'minilatedeliveryandpenalty-capped',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.1997281163930893,
#   'model_output': 'Steve Seller',
#   'true_ans': 'Betty Buyer',
#   'k': 'minilatedeliveryandpenalty-capped',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.051302190870046616,
#   'model_output': '10.5%',
#   'true_ans': '2 days',
#   'k': 'minilatedeliveryandpenalty-capped',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.22601456940174103,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'minilatedeliveryandpenalty-capped',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.10613132268190384,
#   'model_output': '10.5%',
#   'true_ans': '52',
#   'k': 'minilatedeliveryandpenalty-capped',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.1549355387687683,
#   'model_output': '15 days',
#   'true_ans': '15 days',
#   'k': 'minilatedeliveryandpenalty-capped',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.004914156161248684,
#   'model_output': 'within 30 days',
#   'true_ans': '30',
#   'k': 'servicelevelagreement',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.007813705131411552,
#   'model_output': '10%.',
#   'true_ans': '10',
#   'k': 'servicelevelagreement',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.003033560235053301,
#   'model_output': '10%.',
#   'true_ans': '10',
#   'k': 'servicelevelagreement',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.00029329079552553594,
#   'model_output': '5\tReporting',
#   'true_ans': '8',
#   'k': 'servicelevelagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.01248416118323803,
#   'model_output': 'the credits which become due to the Customer',
#   'true_ans': '2 GBP',
#   'k': 'servicelevelagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00022652743791695684,
#   'model_output': '5\tReporting',
#   'true_ans': '98',
#   'k': 'servicelevelagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.023208847269415855,
#   'model_output': 'a deduction against the Customer’s next monthly invoice',
#   'true_ans': '3 GBP',
#   'k': 'servicelevelagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.01830373704433441,
#   'model_output': 'The Supplier "Service Provider" shall provide the Services',
#   'true_ans': 'Service Provider',
#   'k': 'servicelevelagreement',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.011940059252083302,
#   'model_output': 'Service Credit',
#   'true_ans': 'Service Consumer',
#   'k': 'servicelevelagreement',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.044376589357852936,
#   'model_output': 'Steve',
#   'true_ans': 'Steve',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.5304210782051086,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.00863589160144329,
#   'model_output': 'in a 100 miles radius',
#   'true_ans': '100',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.01962858811020851,
#   'model_output': '10.5%',
#   'true_ans': '2 days',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07850675284862518,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07791599631309509,
#   'model_output': '55%',
#   'true_ans': '55',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3175705373287201,
#   'model_output': 'If the delay is more than 15 days',
#   'true_ans': '15 days',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 0.4444444444444445,
#   'em': 0},
#  {'score': 0.2385595142841339,
#   'model_output': 'a full days',
#   'true_ans': 'days',
#   'k': 'latedeliveryandpenalty-optional-this',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.006575651001185179,
#   'model_output': '(i) a percentage (Discount Rate',
#   'true_ans': '1}]',
#   'k': 'volumediscountolist',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.5077163577079773,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'eat-apples',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.028467699885368347,
#   'model_output': 'The canteen only sells apple products',
#   'true_ans': 'ACME',
#   'k': 'eat-apples',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.6737551689147949,
#   'model_output': '4.5%',
#   'true_ans': '5',
#   'k': 'eat-apples',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.7722776532173157,
#   'model_output': '£100,000',
#   'true_ans': '100000 GBP',
#   'k': 'fixed-interests',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.7559189796447754,
#   'model_output': '2.5%',
#   'true_ans': '5',
#   'k': 'fixed-interests',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.09492693096399307,
#   'model_output': '15,',
#   'true_ans': '15',
#   'k': 'fixed-interests',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3648827075958252,
#   'model_output': 'Fred Blogs',
#   'true_ans': 'Fred Blogs',
#   'k': 'helloworld',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3580220341682434,
#   'model_output': 'Katahdin',
#   'true_ans': 'Katahdin',
#   'k': 'project-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.7815762162208557,
#   'model_output': '01/01/2021',
#   'true_ans': '000-04:00',
#   'k': 'project-information',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.8076492547988892,
#   'model_output': '0 USD',
#   'true_ans': '0 USD',
#   'k': 'project-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.04198230057954788,
#   'model_output': 'Ensure that signed contract terms are stored in Salesforce',
#   'true_ans': 'Ensure that signed contract terms are stored in Salesforce',
#   'k': 'project-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.020665384829044342,
#   'model_output': '"I don\'t work on a Friday."\\',
#   'true_ans': '',
#   'k': 'project-information',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04784567281603813,
#   'model_output': 'Clause Token',
#   'true_ans': 'Clause Token',
#   'k': 'saft',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.23999440670013428,
#   'model_output': 'NY corporation',
#   'true_ans': 'Clause',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.2743386924266815,
#   'model_output': 'NY corporation',
#   'true_ans': 'CORP',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.002195091685280204,
#   'model_output': 'NY',
#   'true_ans': 'NY',
#   'k': 'saft',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.06551379710435867,
#   'model_output': 'FINANCIAL SERVICES AND MARKETS ACT 2000',
#   'true_ans': 'True',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.8743612170219421,
#   'model_output': '25 USD',
#   'true_ans': '25 USD',
#   'k': 'saft',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.06493671983480453,
#   'model_output': '2000',
#   'true_ans': 'EUR',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.001698066247627139,
#   'model_output': 'Company Representations',
#   'true_ans': '3000000 USD',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0253610759973526,
#   'model_output': '04/20/2018',
#   'true_ans': '000-04:00',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.8993123173713684,
#   'model_output': '04/20/2018',
#   'true_ans': '000-04:00',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.8592390418052673,
#   'model_output': '38%.',
#   'true_ans': '38',
#   'k': 'saft',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.13256387412548065,
#   'model_output': 'Clause Network',
#   'true_ans': 'Clause Network',
#   'k': 'saft',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.08258094638586044,
#   'model_output': 'U.S. Dollars/Bitcoin',
#   'true_ans': 'Ether',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.039095260202884674,
#   'model_output': 'Applicable Exchange Rate',
#   'true_ans': 'itBit',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.15143489837646484,
#   'model_output': 'NY corporation',
#   'true_ans': 'Peter Hunn',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.2230239361524582,
#   'model_output': 'full legal capacity, power and authority',
#   'true_ans': 'Daniel Charles Selman',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.13071031868457794,
#   'model_output': 'NOTICE TO RESIDENTS OF THE UNITED KINGDOM',
#   'true_ans': 'happiness and intergalactic equality',
#   'k': 'saft',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0005186678608879447,
#   'model_output': 'Widgets" satisfies theAcceptance Criteria',
#   'true_ans': 'Party A',
#   'k': 'acceptance-of-delivery',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0006875218241475523,
#   'model_output': 'Widgets" satisfies theAcceptance Criteria',
#   'true_ans': 'Party B',
#   'k': 'acceptance-of-delivery',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.06728992611169815,
#   'model_output': 'Widgets',
#   'true_ans': 'Widgets',
#   'k': 'acceptance-of-delivery',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.026310916990041733,
#   'model_output': '10 Business Days',
#   'true_ans': '10',
#   'k': 'acceptance-of-delivery',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.46595150232315063,
#   'model_output': 'X',
#   'true_ans': 'Attachment X',
#   'k': 'acceptance-of-delivery',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.13352084159851074,
#   'model_output': 'a limited company incorporated in NY with company number 555',
#   'true_ans': 'ACME',
#   'k': 'safte',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.779309868812561,
#   'model_output': '555',
#   'true_ans': '555',
#   'k': 'safte',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.15994057059288025,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'safte',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3128456473350525,
#   'model_output': 'NY',
#   'true_ans': 'NY',
#   'k': 'safte',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.928604006767273,
#   'model_output': '$25',
#   'true_ans': '25',
#   'k': 'safte',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.6184145212173462,
#   'model_output': '100 minus 7%.',
#   'true_ans': '7',
#   'k': 'safte',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.008866313844919205,
#   'model_output': '\tToken Sale',
#   'true_ans': 'Umbrella',
#   'k': 'safte',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.018822278827428818,
#   'model_output': 'Simple Agreement for Future Tokens or Equity',
#   'true_ans': 'manages umbrella tokens',
#   'k': 'safte',
#   'f1': 0.2,
#   'em': 0},
#  {'score': 0.004013707861304283,
#   'model_output': '\tToken Sale',
#   'true_ans': '12',
#   'k': 'safte',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.004333725199103355,
#   'model_output': '\tToken Sale',
#   'true_ans': 'twelve',
#   'k': 'safte',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.34236449003219604,
#   'model_output': '$25',
#   'true_ans': '1000',
#   'k': 'safte',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.2560393810272217,
#   'model_output': '$25',
#   'true_ans': 'one thousand',
#   'k': 'safte',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.013196960091590881,
#   'model_output': 'Annual Dollar Volume',
#   'true_ans': '1',
#   'k': 'volumediscount',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.002254498889669776,
#   'model_output': 'Annual Dollar Volume',
#   'true_ans': '10',
#   'k': 'volumediscount',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0034255695063620806,
#   'model_output': 'Discount',
#   'true_ans': '3',
#   'k': 'volumediscount',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0015581466723233461,
#   'model_output': 'Discount',
#   'true_ans': '9',
#   'k': 'volumediscount',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.010114886797964573,
#   'model_output': '3%',
#   'true_ans': '8',
#   'k': 'volumediscount',
#   'f1': 0,
#   'em': 0},
#  {'score': 7.180378452176228e-05,
#   'model_output': 'Non-negotiable unless consigned TO ORDER',
#   'true_ans': 'MAERSK LINE',
#   'k': 'bill-of-lading',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07971407473087311,
#   'model_output': 'MAEU',
#   'true_ans': 'MAEU',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.00014390969590749592,
#   'model_output': 'MAEU-ABC12345678',
#   'true_ans': 'MAEU-ABC12345678',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.5159785151481628,
#   'model_output': '2021030264747',
#   'true_ans': '2021030264747',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.17097178101539612,
#   'model_output': '""',
#   'true_ans': '',
#   'k': 'bill-of-lading',
#   'f1': 1,
#   'em': 1},
#  {'score': 0.11924472451210022,
#   'model_output': '""',
#   'true_ans': '',
#   'k': 'bill-of-lading',
#   'f1': 1,
#   'em': 1},
#  {'score': 0.33150357007980347,
#   'model_output': 'CLAUSE TECHNOLOGIES',
#   'true_ans': 'CLAUSE TECHNOLOGIES',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0012048056814819574,
#   'model_output': 'TO ORDER',
#   'true_ans': 'TO ORDER',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.022851383313536644,
#   'model_output': 'SAME AS CONSIGNEE',
#   'true_ans': 'SAME AS CONSIGNEE',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.24481481313705444,
#   'model_output': 'Lagua',
#   'true_ans': 'Lagua',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.6064454913139343,
#   'model_output': '725',
#   'true_ans': '725',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.5747519135475159,
#   'model_output': 'Shanghai, China',
#   'true_ans': 'Shanghai, China',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.5610411763191223,
#   'model_output': 'Brisbane, Australia',
#   'true_ans': 'Brisbane, Australia',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.24014803767204285,
#   'model_output': 'Brisbane, Australia',
#   'true_ans': 'Brisbane, Australia',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.16752080619335175,
#   'model_output': 'Brisbane, Australia',
#   'true_ans': 'Brisbane, Australia',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.00028361528529785573,
#   'model_output': 'Non-negotiable unless consigned TO ORDER',
#   'true_ans': "Commodity', 'quantity': 35, 'unitOfMass': 'TONNE', 'packageType': 'CONTAINER', 'description': 'Wheat', 'nmfcCode': '', 'freightClass': 'CLASS_400', 'hazmat': 'NO'}]",
#   'k': 'bill-of-lading',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.4479994773864746,
#   'model_output': '2500 USD',
#   'true_ans': '2500 USD',
#   'k': 'bill-of-lading',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0009285453124903142,
#   'model_output': '10,000 EUR',
#   'true_ans': 'Dan',
#   'k': 'installment-sale',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0025256189983338118,
#   'model_output': '10,000 EUR',
#   'true_ans': 'Ned',
#   'k': 'installment-sale',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.007258973550051451,
#   'model_output': '10,000 EUR',
#   'true_ans': '10000 EUR',
#   'k': 'installment-sale',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.004105908330529928,
#   'model_output': '1.5%,',
#   'true_ans': '5',
#   'k': 'installment-sale',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.2585289180278778,
#   'model_output': '10,000 EUR',
#   'true_ans': '9500 EUR',
#   'k': 'installment-sale',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.00045831443276256323,
#   'model_output': '10,000 EUR',
#   'true_ans': '500 EUR',
#   'k': 'installment-sale',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.053653378039598465,
#   'model_output': '500 EUR',
#   'true_ans': '500 EUR',
#   'k': 'installment-sale',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.005763044580817223,
#   'model_output': '500 EUR or more per month',
#   'true_ans': '3',
#   'k': 'installment-sale',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.5059033036231995,
#   'model_output': 'Deutsche Bank',
#   'true_ans': 'Deutsche Bank',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.6225950121879578,
#   'model_output': '06/30/2005',
#   'true_ans': '000-04:00',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.7006500363349915,
#   'model_output': 'Fixed Rate Payer',
#   'true_ans': '',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.4178161025047302,
#   'model_output': 'Global No. N397355N',
#   'true_ans': ' N397355N',
#   'k': 'interest-rate-swap',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.6175593733787537,
#   'model_output': '300000000 USD',
#   'true_ans': '300000000 USD',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.14581632614135742,
#   'model_output': '06/30/2005',
#   'true_ans': '000-04:00',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.6400474905967712,
#   'model_output': '06/27/2005',
#   'true_ans': '000-04:00',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.015154791064560413,
#   'model_output': '06/30/2005',
#   'true_ans': '000-04:00',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.4414430856704712,
#   'model_output': '4.09%',
#   'true_ans': 'Counterparty',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04950893670320511,
#   'model_output': '4.09%',
#   'true_ans': 'The 15th day of March, June, September and December of each year, commencing September 15, 2005, through and including the Termination Date with No Adjustment',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.2636873126029968,
#   'model_output': '4.09%',
#   'true_ans': 'The 15th day of March, June, September and December of each year, commencing September 15, 2005, through and including the Termination Date',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.6584914326667786,
#   'model_output': '4.09%',
#   'true_ans': '09',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.4578196704387665,
#   'model_output': '30" "360"',
#   'true_ans': "DayCountFraction', 'value': '30', 'dayCountFractionScheme': '360'}",
#   'k': 'interest-rate-swap',
#   'f1': 0.5714285714285715,
#   'em': 0},
#  {'score': 0.4820624887943268,
#   'model_output': 'New York',
#   'true_ans': 'New York',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.2633916437625885,
#   'model_output': 'Modified Following"',
#   'true_ans': 'Modified Following',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0050047654658555984,
#   'model_output': 'DBAG',
#   'true_ans': 'DBAG',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.003148298244923353,
#   'model_output': 'The 15th day of March, June, September and December of each year',
#   'true_ans': 'The 15th day of March, June, September and December of each year, commencing September 15, 2005, through and including the Termination Date with No Adjustment',
#   'k': 'interest-rate-swap',
#   'f1': 0.5882352941176471,
#   'em': 0},
#  {'score': 0.004456610884517431,
#   'model_output': '4.09%',
#   'true_ans': 'The 15th day of March, June, September and December of each year, commencing September 15, 2005, through and including the Termination Date',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.9773152470588684,
#   'model_output': '3.41%',
#   'true_ans': '41',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.246137797832489,
#   'model_output': 'USD-LIBOR-BBA"',
#   'true_ans': 'USD-LIBOR-BBA',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.31998130679130554,
#   'model_output': 'Three months',
#   'true_ans': 'Three months',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.024169133976101875,
#   'model_output': 'None',
#   'true_ans': 'None',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3015279173851013,
#   'model_output': '30" "360"',
#   'true_ans': "DayCountFraction', 'value': '30', 'dayCountFractionScheme': '360'}",
#   'k': 'interest-rate-swap',
#   'f1': 0.5714285714285715,
#   'em': 0},
#  {'score': 0.016554705798625946,
#   'model_output': '"The first Floating Rate Payer Business Day of each Calculation Period',
#   'true_ans': '',
#   'k': 'interest-rate-swap',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.36317116022109985,
#   'model_output': 'Inapplicable',
#   'true_ans': 'Inapplicable',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.2952039837837219,
#   'model_output': 'New York',
#   'true_ans': 'New York',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.2503248453140259,
#   'model_output': 'Modified Following"',
#   'true_ans': 'Modified Following',
#   'k': 'interest-rate-swap',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.1005517840385437,
#   'model_output': 'Steve',
#   'true_ans': 'Steve',
#   'k': 'latedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.49707457423210144,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'latedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.001208698027767241,
#   'model_output': 'delayed delivery',
#   'true_ans': 'True',
#   'k': 'latedeliveryandpenalty',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.011647365987300873,
#   'model_output': 'more than 15 days',
#   'true_ans': '2 days',
#   'k': 'latedeliveryandpenalty',
#   'f1': 0.3333333333333333,
#   'em': 0},
#  {'score': 0.06406548619270325,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'latedeliveryandpenalty',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0652831643819809,
#   'model_output': '55%',
#   'true_ans': '55',
#   'k': 'latedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3778303861618042,
#   'model_output': 'If the delay is more than 15 days',
#   'true_ans': '15 days',
#   'k': 'latedeliveryandpenalty',
#   'f1': 0.4444444444444445,
#   'em': 0},
#  {'score': 0.1428251564502716,
#   'model_output': 'a full days',
#   'true_ans': 'days',
#   'k': 'latedeliveryandpenalty',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.008631912991404533,
#   'model_output': '180 days',
#   'true_ans': '180 days',
#   'k': 'lateinvoicewithpayment',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.07398960739374161,
#   'model_output': 'Betty Buyer',
#   'true_ans': 'Betty Buyer',
#   'k': 'lateinvoicewithpayment',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.025081679224967957,
#   'model_output': 'Steve Seller',
#   'true_ans': 'Steve Seller',
#   'k': 'lateinvoicewithpayment',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.024329710751771927,
#   'model_output': '"buyer@example.com"',
#   'true_ans': 'Title',
#   'k': 'signature-block-title-name-date',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0546429269015789,
#   'model_output': ':**\\\\"--------"',
#   'true_ans': '--------',
#   'k': 'signature-block-title-name-date',
#   'f1': 1,
#   'em': 1},
#  {'score': 0.05266790837049484,
#   'model_output': '**Full name:**',
#   'true_ans': 'Full Name',
#   'k': 'signature-block-title-name-date',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.027138875797390938,
#   'model_output': '**Date signed:**',
#   'true_ans': 'Date Signed',
#   'k': 'signature-block-title-name-date',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.04720655456185341,
#   'model_output': ':**\\\\"--------"',
#   'true_ans': 'com',
#   'k': 'signature-block-title-name-date',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.8190842866897583,
#   'model_output': '100,000 USD',
#   'true_ans': '100000 USD',
#   'k': 'fixed-interests-static',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.743723452091217,
#   'model_output': '2.5%',
#   'true_ans': '5',
#   'k': 'fixed-interests-static',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.05213429778814316,
#   'model_output': '15,',
#   'true_ans': '15',
#   'k': 'fixed-interests-static',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.7669207453727722,
#   'model_output': '667 USD',
#   'true_ans': '667 USD',
#   'k': 'fixed-interests-static',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0534537211060524,
#   'model_output': 'Example Corp."',
#   'true_ans': '',
#   'k': 'company-information',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.8717089295387268,
#   'model_output': 'Healthcare',
#   'true_ans': 'Healthcare',
#   'k': 'company-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.4905450642108917,
#   'model_output': 'https://example.org',
#   'true_ans': 'org',
#   'k': 'company-information',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.7344240546226501,
#   'model_output': '250',
#   'true_ans': '250',
#   'k': 'company-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.24107328057289124,
#   'model_output': 'Steve',
#   'true_ans': 'Steve',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.5342376232147217,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0012856811517849565,
#   'model_output': 'delayed delivery',
#   'true_ans': 'True',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.006970951799303293,
#   'model_output': 'more than 15 days',
#   'true_ans': '2 days',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 0.3333333333333333,
#   'em': 0},
#  {'score': 0.07577259838581085,
#   'model_output': '55%',
#   'true_ans': '5',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07844618707895279,
#   'model_output': '55%',
#   'true_ans': '55',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.40884849429130554,
#   'model_output': 'If the delay is more than 15 days',
#   'true_ans': '15 days',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 0.4444444444444445,
#   'em': 0},
#  {'score': 0.13549914956092834,
#   'model_output': 'a days is to beconsidered a full days',
#   'true_ans': 'days',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 0.2857142857142857,
#   'em': 0},
#  {'score': 0.08210235089063644,
#   'model_output': 'the prevailing exchange rate at a major United States bank".',
#   'true_ans': 'the prevailing exchange rate at a major United States bank',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0684419572353363,
#   'model_output': 'EUR',
#   'true_ans': 'EUR',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.04521830379962921,
#   'model_output': 'EUR',
#   'true_ans': 'USD',
#   'k': 'latedeliveryandpenalty-currency-conversion',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.1005517840385437,
#   'model_output': 'Steve',
#   'true_ans': 'Steve',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.49707457423210144,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.001208698027767241,
#   'model_output': 'delayed delivery',
#   'true_ans': 'True',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.011647365987300873,
#   'model_output': 'more than 15 days',
#   'true_ans': '2 days',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 0.3333333333333333,
#   'em': 0},
#  {'score': 0.06406548619270325,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0652831643819809,
#   'model_output': '55%',
#   'true_ans': '55',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3778303861618042,
#   'model_output': 'If the delay is more than 15 days',
#   'true_ans': '15 days',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 0.4444444444444445,
#   'em': 0},
#  {'score': 0.1428251564502716,
#   'model_output': 'a full days',
#   'true_ans': 'days',
#   'k': 'latedeliveryandpenalty-else',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.27405592799186707,
#   'model_output': 'double-press the button',
#   'true_ans': 'Dan',
#   'k': 'payment-upon-iot',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0037936002481728792,
#   'model_output': 'the buyer may double-press the button',
#   'true_ans': 'Grant',
#   'k': 'payment-upon-iot',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.006699427496641874,
#   'model_output': '10 USD',
#   'true_ans': '10 USD',
#   'k': 'payment-upon-iot',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.22997382283210754,
#   'model_output': '10 USD',
#   'true_ans': '5',
#   'k': 'payment-upon-iot',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.7180895805358887,
#   'model_output': '01/01/2018',
#   'true_ans': '000-04:00',
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.018204569816589355,
#   'model_output': 'a "NY" "Company"',
#   'true_ans': 'Me',
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.019778862595558167,
#   'model_output': 'a "NY" "Company" with offices located at "1 Broadway",',
#   'true_ans': 'NY',
#   'k': 'copyright-license',
#   'f1': 0.2222222222222222,
#   'em': 0},
#  {'score': 0.00044143840204924345,
#   'model_output': 'paymentClause}}Payment',
#   'true_ans': 'Company',
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.02953474037349224,
#   'model_output': 'Me"',
#   'true_ans': '1 Broadway',
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.32949745655059814,
#   'model_output': 'Myself',
#   'true_ans': 'Myself',
#   'k': 'copyright-license',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.024939728900790215,
#   'model_output': 'Myself',
#   'true_ans': 'NY',
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0026050221640616655,
#   'model_output': 'Permissions',
#   'true_ans': 'Company',
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.13053660094738007,
#   'model_output': 'Myself',
#   'true_ans': '2 Broadway',
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07718533277511597,
#   'model_output': 'United States',
#   'true_ans': 'United States',
#   'k': 'copyright-license',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.00778375705704093,
#   'model_output': 'stuff".',
#   'true_ans': 'stuff',
#   'k': 'copyright-license',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.27164074778556824,
#   'model_output': 'other stuff".',
#   'true_ans': 'other stuff',
#   'k': 'copyright-license',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.14760661125183105,
#   'model_output': 'Payment',
#   'true_ans': "MonetaryAmount', 'doubleValue': 100, 'currencyCode': 'USD'}, 'paymentProcedure': 'bank transfer', 'clauseId': 'ee57349a-245c-4d2b-a740-508baba6d9d9', '$identifier': 'ee57349a-245c-4d2b-a740-508baba6d9d9'}",
#   'k': 'copyright-license',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.23240648210048676,
#   'model_output': 'Betty Buyer',
#   'true_ans': 'Betty Buyer',
#   'k': 'simplelatedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.1601775586605072,
#   'model_output': 'Steve Seller',
#   'true_ans': 'Steve Seller',
#   'k': 'simplelatedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.06038917601108551,
#   'model_output': '10.5%',
#   'true_ans': '2 days',
#   'k': 'simplelatedeliveryandpenalty',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.08273807913064957,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'simplelatedeliveryandpenalty',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0005203780601732433,
#   'model_output': '55%',
#   'true_ans': '55',
#   'k': 'simplelatedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.4111883342266083,
#   'model_output': '15 days',
#   'true_ans': '15 days',
#   'k': 'simplelatedeliveryandpenalty',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.058136723935604095,
#   'model_output': 'Steve',
#   'true_ans': 'Dan',
#   'k': 'full-payment-upon-signature',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0003116974257864058,
#   'model_output': 'Steve',
#   'true_ans': 'Steve',
#   'k': 'full-payment-upon-signature',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.4236317276954651,
#   'model_output': '0.01 USD',
#   'true_ans': '0.01 USD',
#   'k': 'full-payment-upon-signature',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.001784878084436059,
#   'model_output': '4.2 SATICI',
#   'true_ans': 'Umut',
#   'k': 'online-payment-contract-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0012601049384102225,
#   'model_output': '4.2 SATICI',
#   'true_ans': 'Serkan',
#   'k': 'online-payment-contract-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.043604180216789246,
#   'model_output': 'AcmeSoftware-1.0',
#   'true_ans': '0',
#   'k': 'online-payment-contract-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.006791745312511921,
#   'model_output': '8.1.',
#   'true_ans': '2',
#   'k': 'online-payment-contract-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.005924496799707413,
#   'model_output': 'standart program',
#   'true_ans': 'Bölge İdare Mahkemesi',
#   'k': 'online-payment-contract-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.3648827075958252,
#   'model_output': 'Fred Blogs',
#   'true_ans': 'Fred Blogs',
#   'k': 'helloworldstate',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.005926060955971479,
#   'model_output': 'Dan',
#   'true_ans': 'Dave',
#   'k': 'payment-upon-signature',
#   'f1': 0,
#   'em': 0},
#  {'score': 3.524481871863827e-05,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'payment-upon-signature',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.25636425614356995,
#   'model_output': '50 USD',
#   'true_ans': '50 USD',
#   'k': 'payment-upon-signature',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0024971780367195606,
#   'model_output': '1. a percentage (Discount Rate',
#   'true_ans': '1}]',
#   'k': 'volumediscountulist',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.004995729308575392,
#   'model_output': 'TAAHHÜTNAME',
#   'true_ans': 'Acme Car Rental',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00022445619106292725,
#   'model_output': '',
#   'true_ans': 'Dikmen Caddesi No:48/15 Dikmen Ankara',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00025356232072226703,
#   'model_output': '',
#   'true_ans': '+901231231234',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.035645417869091034,
#   'model_output': 'TAAHHÜTNAME',
#   'true_ans': 'Can Doğan',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.009332273155450821,
#   'model_output': 'teslim etmiştir',
#   'true_ans': ' Kennedy Sokak No:23/12 Kavaklıdere Ankara',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.017839035019278526,
#   'model_output': 'teslim etmiştir',
#   'true_ans': '+901234567890',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.05740178003907204,
#   'model_output': 'KİRAYA VEREN',
#   'true_ans': 'Ankara',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.06215473636984825,
#   'model_output': 'Plaka No "PlakaNo"',
#   'true_ans': 'PlakaNo',
#   'k': 'car-rental-tr',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.029385875910520554,
#   'model_output': 'Volkswagen',
#   'true_ans': 'Volkswagen',
#   'k': 'car-rental-tr',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.10955806821584702,
#   'model_output': 'Golf 1.6 TDI Comfortline',
#   'true_ans': '6 TDI Comfortline',
#   'k': 'car-rental-tr',
#   'f1': 0.5714285714285715,
#   'em': 0},
#  {'score': 0.042872678488492966,
#   'model_output': 'KİRAYA VEREN',
#   'true_ans': '2017',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0006726370193064213,
#   'model_output': '',
#   'true_ans': 'Kırmızı',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0020805741660296917,
#   'model_output': 'gelebilecek',
#   'true_ans': 'WVWZZZ3CZXW000001',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0009380780393257737,
#   'model_output': '',
#   'true_ans': '2018',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.014188115485012531,
#   'model_output': 'KİRAYA VEREN',
#   'true_ans': '2018',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0011967048048973083,
#   'model_output': 'KİRAYA VEREN',
#   'true_ans': 'Acme Car Rental Merkez Ofis',
#   'k': 'car-rental-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.05304042994976044,
#   'model_output': 'bank transfer',
#   'true_ans': "99, 'currencyCode': 'USD'}, 'paymentProcedure': 'bank transfer', 'clauseId': '0bd384b0-cf8e-42c7-b87c-96f6847a0cc1', '$identifier': '0bd384b0-cf8e-42c7-b87c-96f6847a0cc1'}",
#   'k': 'car-rental-tr',
#   'f1': 0.33333333333333337,
#   'em': 0},
#  {'score': 0.003222438972443342,
#   'model_output': 'Diana',
#   'true_ans': 'Michael',
#   'k': 'payment-upon-delivery',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00020703602058347315,
#   'model_output': 'Diana',
#   'true_ans': 'Diana',
#   'k': 'payment-upon-delivery',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.7301552891731262,
#   'model_output': '9.99 USD',
#   'true_ans': '9.99 USD',
#   'k': 'payment-upon-delivery',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.7701584696769714,
#   'model_output': '1.99 USD',
#   'true_ans': '1.99 USD',
#   'k': 'payment-upon-delivery',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3648827075958252,
#   'model_output': 'Fred Blogs',
#   'true_ans': 'Fred Blogs',
#   'k': 'hellomodule',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.044376589357852936,
#   'model_output': 'Steve',
#   'true_ans': 'Steve',
#   'k': 'latedeliveryandpenalty-optional',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.5304210782051086,
#   'model_output': 'Dan',
#   'true_ans': 'Dan',
#   'k': 'latedeliveryandpenalty-optional',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.01962858811020851,
#   'model_output': '10.5%',
#   'true_ans': '2 days',
#   'k': 'latedeliveryandpenalty-optional',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07850675284862518,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'latedeliveryandpenalty-optional',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07791599631309509,
#   'model_output': '55%',
#   'true_ans': '55',
#   'k': 'latedeliveryandpenalty-optional',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.3175705373287201,
#   'model_output': 'If the delay is more than 15 days',
#   'true_ans': '15 days',
#   'k': 'latedeliveryandpenalty-optional',
#   'f1': 0.4444444444444445,
#   'em': 0},
#  {'score': 0.2385595142841339,
# ...
#   'true_ans': '3',
#   'k': 'supplyagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.06466995924711227,
#   'model_output': 'Annex A',
#   'true_ans': 'Annex B',
#   'k': 'supplyagreement',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.0032204696908593178,
#   'model_output': "All prices are FOB the Supplier's designated shipping point",
#   'true_ans': '15',
#   'k': 'supplyagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.4822559356689453,
#   'model_output': 'XXX-XX',
#   'true_ans': 'XXX-XX',
#   'k': 'supplyagreement',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.6230940818786621,
#   'model_output': 'YYY-YY',
#   'true_ans': 'YYY-YY',
#   'k': 'supplyagreement',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0023874801117926836,
#   'model_output': 'Limited Warranty',
#   'true_ans': '2',
#   'k': 'supplyagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.15054988861083984,
#   'model_output': '1 years length',
#   'true_ans': '1',
#   'k': 'supplyagreement',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.057026807218790054,
#   'model_output': '1 years length',
#   'true_ans': '30',
#   'k': 'supplyagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.013813608326017857,
#   'model_output': 'Governing Law',
#   'true_ans': 'NY',
#   'k': 'supplyagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.05218300595879555,
#   'model_output': 'any state or federal court',
#   'true_ans': 'NY',
#   'k': 'supplyagreement',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.06459467858076096,
#   'model_output': '"PETER',
#   'true_ans': 'PETER',
#   'k': 'demandforecast',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.6627575755119324,
#   'model_output': 'DAN',
#   'true_ans': 'DAN',
#   'k': 'demandforecast',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.015042469836771488,
#   'model_output': '04/02/2018',
#   'true_ans': '000-04:00',
#   'k': 'demandforecast',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.06302709877490997,
#   'model_output': '85%',
#   'true_ans': '85',
#   'k': 'demandforecast',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0037520972546190023,
#   'model_output': '6.1.\tС',
#   'true_ans': 'покупатель',
#   'k': 'sales-contract-ru',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.005348035600036383,
#   'model_output': '4.5',
#   'true_ans': 'продавец',
#   'k': 'sales-contract-ru',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.011850686743855476,
#   'model_output': '4.5.\t',
#   'true_ans': '6 (шести)',
#   'k': 'sales-contract-ru',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0020275802817195654,
#   'model_output': '1.1.\t',
#   'true_ans': 'партиями',
#   'k': 'sales-contract-ru',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.005085465032607317,
#   'model_output': '4.5.\t',
#   'true_ans': 'в российские рубли',
#   'k': 'sales-contract-ru',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.015934595838189125,
#   'model_output': '4.5.\t',
#   'true_ans': '7',
#   'k': 'sales-contract-ru',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.010953662917017937,
#   'model_output': '4.3',
#   'true_ans': 'законодательством Российская Федерация',
#   'k': 'sales-contract-ru',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.8294198513031006,
#   'model_output': '01/20/2021',
#   'true_ans': '000-04:00',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.12387429922819138,
#   'model_output': 'Delaware corporation',
#   'true_ans': 'Acme Exports',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.05661754682660103,
#   'model_output': "Dan's Imports",
#   'true_ans': "Dan's Imports",
#   'k': 'supply-agreement-loc',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.14546233415603638,
#   'model_output': 'Widgets',
#   'true_ans': 'Widgets',
#   'k': 'supply-agreement-loc',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.005642682313919067,
#   'model_output': '{{% importerLOCAmount/2 %}}',
#   'true_ans': '',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.5696994662284851,
#   'model_output': '01/21/2021',
#   'true_ans': '000-04:00',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0016521315556019545,
#   'model_output': 'Big Bank Corp."\\',
#   'true_ans': '',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.002782895229756832,
#   'model_output': '{{% importerLOCAmount/2 %}}',
#   'true_ans': '1234567',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.08691111952066422,
#   'model_output': '{{% importerLOCAmount/2 %}}',
#   'true_ans': '1000000 SEK',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0003498756850603968,
#   'model_output': 'Notices',
#   'true_ans': 'ORDER-001',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.12652505934238434,
#   'model_output': 'PACKING-001',
#   'true_ans': 'PACKING-001',
#   'k': 'supply-agreement-loc',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.032263174653053284,
#   'model_output': 'Term Definition',
#   'true_ans': '2',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04892759397625923,
#   'model_output': 'Renewal Term by Notice',
#   'true_ans': '5 years',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.026855917647480965,
#   'model_output': 'Letter of Credit',
#   'true_ans': '90 days',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.08509527891874313,
#   'model_output': '1000000 SEK',
#   'true_ans': 'INVOICE-001',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.5773731470108032,
#   'model_output': 'BOOKING-001',
#   'true_ans': 'BOOKING-001',
#   'k': 'supply-agreement-loc',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.012891110964119434,
#   'model_output': 'Orders',
#   'true_ans': 'PO-001',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.028916925191879272,
#   'model_output': '{[exporter}} consents in writing',
#   'true_ans': '',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.07403289526700974,
#   'model_output': '01/30/2021',
#   'true_ans': '7',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.00035379291512072086,
#   'model_output': '100',
#   'true_ans': '100',
#   'k': 'supply-agreement-loc',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.00023465469712391496,
#   'model_output': 'Notices   ',
#   'true_ans': '300 SEK',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.5419626235961914,
#   'model_output': 'Los Angeles',
#   'true_ans': '34 Elm Street',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.1348237544298172,
#   'model_output': '01/30/2021',
#   'true_ans': '000-04:00',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0007689769845455885,
#   'model_output': 'No General Waivers',
#   'true_ans': '142635263523',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0008919319952838123,
#   'model_output': '4. Modification',
#   'true_ans': 'PO-001-A',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.006162520032376051,
#   'model_output': '90 days',
#   'true_ans': '7 days',
#   'k': 'supply-agreement-loc',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.5095145106315613,
#   'model_output': 'Acme Exports',
#   'true_ans': 'DHS',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0028485688380897045,
#   'model_output': 'Dan\'s Imports", a company organized and existing under the laws of Sweden',
#   'true_ans': 'Los Angeles',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.013566340319812298,
#   'model_output': 'Acme Exports',
#   'true_ans': 'Malmo',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.1133185401558876,
#   'model_output': 'workmanlike quality',
#   'true_ans': 'Widgets',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.6075194478034973,
#   'model_output': '100',
#   'true_ans': '100',
#   'k': 'supply-agreement-loc',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.49966317415237427,
#   'model_output': '50 cm x 10 cm x 60 cm',
#   'true_ans': '50 cm x 10 cm x 60 cm',
#   'k': 'supply-agreement-loc',
#   'f1': 0.625,
#   'em': 1},
#  {'score': 0.7271053791046143,
#   'model_output': '4000 SEK',
#   'true_ans': '4000 SEK',
#   'k': 'supply-agreement-loc',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.08296889066696167,
#   'model_output': '01/30/2021',
#   'true_ans': '7 days',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.011921132914721966,
#   'model_output': 'Annex B',
#   'true_ans': 'good are acceptable',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.012544522061944008,
#   'model_output': '01/21/2021',
#   'true_ans': '000-04:00',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.02399883046746254,
#   'model_output': 'Term Definition',
#   'true_ans': '3 years',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.7214288115501404,
#   'model_output': 'Renewal Term',
#   'true_ans': '2 years',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.285199910402298,
#   'model_output': '001',
#   'true_ans': 'Shipment 001',
#   'k': 'supply-agreement-loc',
#   'f1': 0.6666666666666666,
#   'em': 0},
#  {'score': 0.0014302474446594715,
#   'model_output': '1000000 SEK',
#   'true_ans': '4000 SEK',
#   'k': 'supply-agreement-loc',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.028059890493750572,
#   'model_output': 'Widgets',
#   'true_ans': '10',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.04297085478901863,
#   'model_output': '10 per days',
#   'true_ans': '10',
#   'k': 'supply-agreement-loc',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.01287689246237278,
#   'model_output': '01/20/2021',
#   'true_ans': 'days',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0061650751158595085,
#   'model_output': '100 on the "PO-001".',
#   'true_ans': '10 days',
#   'k': 'supply-agreement-loc',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.02322780154645443,
#   'model_output': '"Dan" shall pay the full purchase price to "Jerome',
#   'true_ans': 'Dan',
#   'k': 'full-payment-upon-demand',
#   'f1': 0.2222222222222222,
#   'em': 0},
#  {'score': 4.482803342398256e-05,
#   'model_output': '"Jerome',
#   'true_ans': 'Jerome',
#   'k': 'full-payment-upon-demand',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.39611294865608215,
#   'model_output': '3.14 EUR',
#   'true_ans': '3.14 EUR',
#   'k': 'full-payment-upon-demand',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.14035561680793762,
#   'model_output': 'Betty Buyer',
#   'true_ans': 'Steve Seller',
#   'k': 'minilatedeliveryandpenalty-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.1997281163930893,
#   'model_output': 'Steve Seller',
#   'true_ans': 'Betty Buyer',
#   'k': 'minilatedeliveryandpenalty-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.051302190870046616,
#   'model_output': '10.5%',
#   'true_ans': '2 days',
#   'k': 'minilatedeliveryandpenalty-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.22601456940174103,
#   'model_output': '10.5%',
#   'true_ans': '5',
#   'k': 'minilatedeliveryandpenalty-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.10613132268190384,
#   'model_output': '10.5%',
#   'true_ans': '52',
#   'k': 'minilatedeliveryandpenalty-payment',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.1549355387687683,
#   'model_output': '15 days',
#   'true_ans': '15 days',
#   'k': 'minilatedeliveryandpenalty-payment',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.22690574824810028,
#   'model_output': 'Michael',
#   'true_ans': 'Michael',
#   'k': 'rental-deposit',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0004424058715812862,
#   'model_output': '"Parsa',
#   'true_ans': 'Parsa',
#   'k': 'rental-deposit',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.05965797230601311,
#   'model_output': '3000 USD',
#   'true_ans': '3000 USD',
#   'k': 'rental-deposit',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.0003905793419107795,
#   'model_output': 'Monetary Deposit',
#   'true_ans': '30 days',
#   'k': 'rental-deposit',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.46763908863067627,
#   'model_output': '0.98 times',
#   'true_ans': '98',
#   'k': 'rental-deposit',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0039787315763533115,
#   'model_output': 'New Jersey",',
#   'true_ans': 'New Jersey',
#   'k': 'rental-deposit',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.006052677053958178,
#   'model_output': 'New Jersey',
#   'true_ans': 'NJSD',
#   'k': 'rental-deposit',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.08163338154554367,
#   'model_output': 'Bank of America',
#   'true_ans': 'Bank of America',
#   'k': 'rental-deposit',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.001546400017105043,
#   'model_output': 'Within 3 weeks after the end of the Term',
#   'true_ans': '3 weeks',
#   'k': 'rental-deposit',
#   'f1': 0.4444444444444445,
#   'em': 0},
#  {'score': 1.746697125781793e-05,
#   'model_output': 'C. Disposition of Monetary Deposit',
#   'true_ans': 'Schedule A',
#   'k': 'rental-deposit',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.007422199472784996,
#   'model_output': 'Jane Doe',
#   'true_ans': 'Jane Doe',
#   'k': 'contact-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.40513351559638977,
#   'model_output': 'CIO',
#   'true_ans': 'CIO',
#   'k': 'contact-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.10328993946313858,
#   'model_output': 'jane@example.com"',
#   'true_ans': 'com',
#   'k': 'contact-information',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.550614058971405,
#   'model_output': '123-456-789',
#   'true_ans': '123-456-789',
#   'k': 'contact-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.6390795707702637,
#   'model_output': 'America_New_York',
#   'true_ans': 'America_New_York',
#   'k': 'contact-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.06042811647057533,
#   'model_output': 'EMAIL',
#   'true_ans': 'EMAIL',
#   'k': 'contact-information',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.1293506920337677,
#   'model_output': 'PETER" 1.50 USD per KG',
#   'true_ans': 'PETER',
#   'k': 'perishable-goods',
#   'f1': 0.33333333333333337,
#   'em': 0},
#  {'score': 0.496517539024353,
#   'model_output': 'DAN',
#   'true_ans': 'DAN',
#   'k': 'perishable-goods',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.06487693637609482,
#   'model_output': 'SHIP_001',
#   'true_ans': 'SHIP_001',
#   'k': 'perishable-goods',
#   'f1': 1.0,
#   'em': 1},
#  {'score': 0.01664215326309204,
#   'model_output': '07/02/2018',
#   'true_ans': '000-04:00',
#   'k': 'perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.009897659532725811,
#   'model_output': '1.50 USD per KG',
#   'true_ans': '1.5 USD',
#   'k': 'perishable-goods',
#   'f1': 0.3333333333333333,
#   'em': 0},
#  {'score': 0.03230644389986992,
#   'model_output': 'SHIP_001',
#   'true_ans': 'KG',
#   'k': 'perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0002538343542255461,
#   'model_output': 'number of shipment units',
#   'true_ans': '3000',
#   'k': 'perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 3.7625592085532844e-05,
#   'model_output': '0.2.',
#   'true_ans': '3500',
#   'k': 'perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.31983721256256104,
#   'model_output': 'Zutano Mexican Avocados',
#   'true_ans': 'Grade I, Size 4, Zutano Mexican Avocados',
#   'k': 'perishable-goods',
#   'f1': 0.6,
#   'em': 0},
#  {'score': 0.11149559915065765,
#   'model_output': '1 per hours',
#   'true_ans': '1',
#   'k': 'perishable-goods',
#   'f1': 0.5,
#   'em': 0},
#  {'score': 0.00012166003580205142,
#   'model_output': '07/02/2018',
#   'true_ans': 'hours',
#   'k': 'perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.028940968215465546,
#   'model_output': 'between 2 and 13.',
#   'true_ans': '2',
#   'k': 'perishable-goods',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.03313613310456276,
#   'model_output': 'between 2 and 13.',
#   'true_ans': '13',
#   'k': 'perishable-goods',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.10944656282663345,
#   'model_output': 'between 70 and 90',
#   'true_ans': '70',
#   'k': 'perishable-goods',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.12117263674736023,
#   'model_output': 'between 70 and 90.',
#   'true_ans': '90',
#   'k': 'perishable-goods',
#   'f1': 0.4,
#   'em': 0},
#  {'score': 0.1851242482662201,
#   'model_output': '0.2',
#   'true_ans': '2',
#   'k': 'perishable-goods',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.06553766876459122,
#   'model_output': 'ACME Corp."',
#   'true_ans': 'Can Doğan',
#   'k': 'one-time-payment-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.0076895663514733315,
#   'model_output': 'BİLGİLENDİRME',
#   'true_ans': '',
#   'k': 'one-time-payment-tr',
#   'f1': 0,
#   'em': 0},
#  {'score': 0.31971532106399536,
#   'model_output': '1922.99 TRY',
#   'true_ans': '1922.99 TRY',
#   'k': 'one-time-payment-tr',
#   'f1': 1.0,
#   'em': 1}]

# %%
res
# Out:
# {'score': 0.31971532106399536,
#  'start': 2454,
#  'end': 2465,
#  'answer': '1922.99 TRY'}

# %%
questions
# Out:
# {'variable_name': 'paymentPeriodWithPermission',
#  'ans': '7 days',
#  'variable_value': {'$class': 'org.accordproject.time.Duration',
#   'amount': 7,
#   'unit': 'days'}}

# %%
res
# Out:
# {'score': 0.000850165612064302,
#  'start': 1244,
#  'end': 1329,
#  'answer': 'Licensee shall request permission from the governmental authority to make the payment'}

# %%
questions
# Out:
# {'variable_name': 'paymentPeriodWithPermission',
#  'ans': '7 days',
#  'variable_value': {'$class': 'org.accordproject.time.Duration',
#   'amount': 7,
#   'unit': 'days'}}

# %%
# Out:
# 'supplier'

# %%
# Out:
# [{'variable_name': 'maximumDelay',
#   'ans': '180 days',
#   'variable_value': {'$class': 'org.accordproject.time.Duration',
#    'amount': 180,
#    'unit': 'days'}},
#  {'variable_name': 'purchaser',
#   'ans': 'Betty Buyer',
#   'variable_value': 'resource:org.accordproject.party.Party#Betty%20Buyer'},
#  {'variable_name': 'supplier',
#   'ans': 'Steve Seller',
#   'variable_value': 'resource:org.accordproject.party.Party#Steve%20Seller'}]

# %%
variable_value = QAs['latedeliveryandpenalty']["Qs"][-2]['variable_value']

# %%
QAs['latedeliveryandpenalty']["Qs"][-2]
# Out:
# {'variable_name': 'termination', 'ans': '15 days', 'variable_value': '15 days'}

# %%
variable_value = json.loads(variable_value.replace("'", '"'))
for key in variable_value.keys():
    if key in ['amount']:
        ans = f"{variable_value[key]} {variable_value['unit']}"
        break
    elif 'value' in key.lower():
        pass
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_4062/1455817103.py in <module>
# ----> 1 variable_value = json.loads(variable_value.replace("'", '"'))
#       2 for key in variable_value.keys():
#       3     if key in ['amount']:
#       4         ans = f"{variable_value[key]} {variable_value['unit']}"
#       5         break
#
# AttributeError: 'dict' object has no attribute 'replace'

# %%
ans
# Out:
# '15 days'

# %%
QAs.keys()
# Out:
# dict_keys(['saft', 'payment-upon-signature', 'sales-contract-ru', 'certificate-of-incorporation', 'promissory-note', 'empty', 'payment-upon-delivery', 'acceptance-of-delivery', 'safte', 'empty-contract', 'latedeliveryandpenalty-currency-conversion', 'fragile-goods', 'minilatedeliveryandpenalty-capped', 'minilatedeliveryandpenalty-payment', 'promissory-note-md', 'latedeliveryandpenalty', 'servicelevelagreement', 'latedeliveryandpenalty-optional', 'supplyagreement-perishable-goods', 'full-payment-upon-demand', 'helloworldstate', 'one-time-payment-tr', 'car-rental-tr', 'perishable-goods', 'fixed-interests-static', 'simplelatedeliveryandpenalty', 'minilatedeliveryandpenalty', 'copyright-license', 'installment-sale', 'hellomodule', 'online-payment-contract-tr', 'payment-upon-iot', 'signature-block-title-name-date', 'demandforecast', 'fixed-interests', 'full-payment-upon-signature', 'contact-information', 'volumediscount', 'volumediscountulist', 'company-information', 'eat-apples', 'latedeliveryandpenalty-optional-this', 'bill-of-lading', 'supply-agreement-loc', 'latedeliveryandpenalty-else', 'helloworld', 'ip-payment', 'project-information', 'rental-deposit', 'supplyagreement', 'interest-rate-swap', 'volumediscountolist', 'lateinvoicewithpayment'])

# %%
variable_value
# Out:
# '16ddc768-3847-4fc6-a7e4-9b7d94c020dd'

# %%
# Out:
# '## Acceptance of Delivery.\n\n{{shipper}} will be deemed to have completed its delivery obligations\nif in {{receiver}}\'s opinion, the {{deliverable}} satisfies the\nAcceptance Criteria, and {{receiver}} notifies {{shipper}} in writing\nthat it is accepting the {{deliverable}}.\n\n## Inspection and Notice.\n\n{{receiver}} will have {{businessDays}} Business Days to inspect and\nevaluate the {{deliverable}} on the delivery date before notifying\n{{shipper}} that it is either accepting or rejecting the\n{{deliverable}}.\n\n## Acceptance Criteria.\n\nThe "Acceptance Criteria" are the specifications the {{deliverable}}\nmust meet for {{shipper}} to comply with its requirements and\nobligations under this agreement, detailed in {{attachment}}, attached\nto this agreement.'

# %%
variable_value
# Out:
# '16ddc768-3847-4fc6-a7e4-9b7d94c020dd'

# %%
variable_name, question
# Out:
# ('shipper', 'resource:org.accordproject.organization.Organization#Party%20A')

# %%
v
# Out:
# {'$class': 'org.accordproject.acceptanceofdelivery.AcceptanceOfDeliveryClause',
#  'shipper': 'resource:org.accordproject.organization.Organization#Party%20A',
#  'receiver': 'resource:org.accordproject.organization.Organization#Party%20B',
#  'deliverable': 'Widgets',
#  'businessDays': 10,
#  'attachment': 'Attachment X',
#  'clauseId': '16ddc768-3847-4fc6-a7e4-9b7d94c020dd',
#  '$identifier': '16ddc768-3847-4fc6-a7e4-9b7d94c020dd'}

# %%
# Out:
# 'resource:org.accordproject.organization.Organization#Party A'

# %%
question.split("#")[1]
# Out:
# 'Party%20A'

# %%
k
# Out:
# 'acceptance-of-delivery'

# %%
data['latedeliveryandpenalty']['/text/sample.md']
# Out:
# ['## Late Delivery and Penalty.\n',
#  '\n',
#  'In case of delayed delivery except for Force Majeure cases,\n',
#  '"Dan" (the Seller) shall pay to "Steve" (the Buyer) for every 2 days\n',
#  'of delay penalty amounting to 10.5% of the total value of the Equipment\n',
#  'whose delivery has been delayed. Any fractional part of a days is to be\n',
#  'considered a full days. The total amount of penalty shall not however,\n',
#  'exceed 55% of the total value of the Equipment involved in late delivery.\n',
#  'If the delay is more than 15 days, the Buyer is entitled to terminate this Contract.']

# %%
import re

# %%
res = re.findall("(?<=\{{).+?(?=\}})", 
                 "".join(data['latedeliveryandpenalty']['/text/grammar.tem.md']))

res

# %% [markdown]
# https://templates.accordproject.org/latedeliveryandpenalty@0.15.0.html

# %%
"".join(data['latedeliveryandpenalty']['/text/sample.md'])
# Out:
# '## Late Delivery and Penalty.\n\nIn case of delayed delivery except for Force Majeure cases,\n"Dan" (the Seller) shall pay to "Steve" (the Buyer) for every 2 days\nof delay penalty amounting to 10.5% of the total value of the Equipment\nwhose delivery has been delayed. Any fractional part of a days is to be\nconsidered a full days. The total amount of penalty shall not however,\nexceed 55% of the total value of the Equipment involved in late delivery.\nIf the delay is more than 15 days, the Buyer is entitled to terminate this Contract.'

# %%
"".join(data['latedeliveryandpenalty']['/text/grammar.tem.md'])
# Out:
# '## Late Delivery and Penalty.\n\nIn case of delayed delivery{{#if forceMajeure}} except for Force Majeure cases,{{/if}}\n{{seller}} (the Seller) shall pay to {{buyer}} (the Buyer) for every {{penaltyDuration}}\nof delay penalty amounting to {{penaltyPercentage}}% of the total value of the Equipment\nwhose delivery has been delayed. Any fractional part of a {{fractionalPart}} is to be\nconsidered a full {{fractionalPart}}. The total amount of penalty shall not however,\nexceed {{capPercentage}}% of the total value of the Equipment involved in late delivery.\nIf the delay is more than {{termination}}, the Buyer is entitled to terminate this Contract.'
