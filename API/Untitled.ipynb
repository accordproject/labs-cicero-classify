# %%
# !wget http://ai.glis.jupyter.eason.tw:8000/0814_v3.zip
# Out:
# --2021-08-18 06:09:32--  http://ai.glis.jupyter.eason.tw:8000/0814_v3.zip
# Resolving ai.glis.jupyter.eason.tw (ai.glis.jupyter.eason.tw)... 140.122.104.37
# Connecting to ai.glis.jupyter.eason.tw (ai.glis.jupyter.eason.tw)|140.122.104.37|:8000... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 110012938 (105M) [application/zip]
# Saving to: ‘0814_v3.zip’
#
# 0814_v3.zip         100%[===================>] 104.92M  11.1MB/s    in 9.4s
#
# 2021-08-18 06:09:42 (11.1 MB/s) - ‘0814_v3.zip’ saved [110012938/110012938]

# %%
# !unzip 0814_v3.zip
# Out:
# Archive:  0814_v3.zip
#    creating: save_adapters/B-art_epoch_3_0814_v3/
#   inflating: save_adapters/B-art_epoch_3_0814_v3/pytorch_model_head.bin
#   inflating: save_adapters/B-art_epoch_3_0814_v3/adapter_config.json
#   inflating: save_adapters/B-art_epoch_3_0814_v3/head_config.json
#   inflating: save_adapters/B-art_epoch_3_0814_v3/pytorch_adapter.bin
#    creating: save_adapters/B-eve_epoch_3_0814_v3/
#   inflating: save_adapters/B-eve_epoch_3_0814_v3/pytorch_model_head.bin
#   inflating: save_adapters/B-eve_epoch_3_0814_v3/adapter_config.json
#   inflating: save_adapters/B-eve_epoch_3_0814_v3/head_config.json
#   inflating: save_adapters/B-eve_epoch_3_0814_v3/pytorch_adapter.bin
#    creating: save_adapters/B-geo_epoch_3_0814_v3/
#   inflating: save_adapters/B-geo_epoch_3_0814_v3/pytorch_model_head.bin
#   inflating: save_adapters/B-geo_epoch_3_0814_v3/adapter_config.json
#   inflating: save_adapters/B-geo_epoch_3_0814_v3/head_config.json
# ...
